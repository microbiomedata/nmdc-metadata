# %%
import json
import pandas as pds
import jsonasobj
import lib.nmdc as nmdc
import lib.data_operations as dop

# %% [markdown]
# ### Read biosample data into dataframe
# Steps:
# - define file name contaning data
# - define subset of columns to use in the data frame
# - when testing, define nrows to limit number of rows

# %%
file_name = "data/export.sql/BIOSAMPLE_DATA_TABLE.dsv"

# %%
subset_cols = \
    ['biosample_id',
     'biosample_name',
     'description',
     'add_date',
     'mod_date',
     'ecosystem_path_id',
     'ecosystem',
     'ecosystem_category',
     'ecosystem_type',
     'ecosystem_subtype',
     'specific_ecosystem',
     'habitat',
     'location',
     'community',
     'ncbi_taxonomy_name',
     'geographic_location',
     'latitude',
     'longitude',
     'sample_collection_site',
     'identifier',
     'sample_collection_year',
     'sample_collection_month',
     'sample_collection_day',
     'sample_collection_hour',
     'sample_collection_minute',
     'host_name',
     'depth',
     'subsurface_depth',
     'altitude',
     'temperature_range',
     'proport_woa_temperature',
     'biogas_temperature',
     'growth_temperature',
     'soil_annual_season_temp',
     'water_samp_store_temp',
     'biogas_retention_time',
     'salinity',
     'pressure',
     'ph',
     'chlorophyll_concentration',
     'nitrate_concentration',
     'oxygen_concentration',
     'salinity_concentration'
    ]

# %%
nrows = 5 # set to None for all records
save_file_name = "output/schema-test.json"
df = dop.make_dataframe(file_name, subset_cols=subset_cols, nrows=nrows)

# %%
df.head() # peek at data
# Out:
#    biosample_id                                     biosample_name  \
# 0        186408  Enriched soil aggregate microbial communities ...
# 1        186444  Enriched soil aggregate microbial communities ...
# 2        156554  Enriched cells from forest soil in Barre Woods...
# 3        156649  Enriched cells from forest soil in Barre Woods...
# 4        156728  Enriched cells from forest soil in Barre Woods...
#
#                                          description  \
# 0  Enriched soil aggregate microbial communities ...
# 1  Enriched soil aggregate microbial communities ...
# 2  Enriched cells from forest soil in Barre Woods...
# 3  Enriched cells from forest soil in Barre Woods...
# 4  Enriched cells from forest soil in Barre Woods...
#
#                           add_date                         mod_date  \
# 0  23-FEB-18 01.10.55.869000000 PM  17-JUN-19 10.32.13.358000000 PM
# 1  23-FEB-18 01.11.30.021000000 PM  30-SEP-19 09.28.26.880000000 PM
# 2  28-JUL-17 03.31.05.630000000 PM  18-JUN-19 08.18.47.034000000 AM
# 3  28-JUL-17 03.56.33.303000000 PM  18-JUN-19 04.42.05.420000000 PM
# 4  28-JUL-17 04.22.48.318000000 PM  18-JUN-19 05.54.01.541000000 PM
#
#    ecosystem_path_id      ecosystem ecosystem_category ecosystem_type  \
# 0               4212  Environmental        Terrestrial   Unclassified
# 1               4212  Environmental        Terrestrial           Soil
# 2               4205  Environmental        Terrestrial           Soil
# 3               4205  Environmental        Terrestrial           Soil
# 4               4205  Environmental        Terrestrial           Soil
#
#   ecosystem_subtype  ... soil_annual_season_temp water_samp_store_temp  \
# 0               NaN  ...                     NaN                   NaN
# 1      Unclassified  ...                     NaN                   NaN
# 2      Unclassified  ...                     NaN                   NaN
# 3      Unclassified  ...                     NaN                   NaN
# 4      Unclassified  ...                     NaN                   NaN
#
#   biogas_retention_time salinity pressure  ph  chlorophyll_concentration  \
# 0                   NaN      NaN      NaN NaN                        NaN
# 1                   NaN      NaN      NaN NaN                        NaN
# 2                   NaN      NaN      NaN NaN                        NaN
# 3                   NaN      NaN      NaN NaN                        NaN
# 4                   NaN      NaN      NaN NaN                        NaN
#
#    nitrate_concentration oxygen_concentration salinity_concentration
# 0                    NaN                  NaN                    NaN
# 1                    NaN                  NaN                    NaN
# 2                    NaN                  NaN                    NaN
# 3                    NaN                  NaN                    NaN
# 4                    NaN                  NaN                    NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Convert dataframe to dictionary

# %%
dictdf = df.to_dict(orient="records")

# %%
## print out a single record for viewing
for record in dictdf:
    print(json.dumps(record, indent=4)); break

# %% [markdown]
# ### Iterate over dataframe dictionary and build a list of json strings

# %%
json_list = dop.make_json_string_list(dictdf, nmdc.Biosample, 'biosample_id', 'biosample_name')

# %%
print(json_list[1]) ## peek at data

# %% [markdown]
# ### Save json list to file

# %%
dop.save_json_string_list(save_file_name, json_list)
